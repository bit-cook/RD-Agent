# %%
import tarfile

tar_path = "/data/userdata/v-lijingyuan/JobAndExp/amlt_project/amlt/measured-chipmunk/20251229-221813_mlsp-2013-birds/mlsp-2013-birds.workspace.tar"
extract_dir = "./workspace_mlsp_birds"

with tarfile.open(tar_path, "r") as tar:
    tar.extractall(extract_dir)

print("解压完成:", extract_dir)
